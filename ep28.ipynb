# %%
import requests

# %%
image_url = "http://cdn.homelife.com.au/images/51305/flower-macro-20160229135746~q75,dx2400y-u0r1g0,c--.jpg"

# %%
image_binary = requests.get(image_url).content

with open("flower.jpg", "wb") as f:
    f.write(image_binary)

# %%
from PIL import Image

flower_image = Image.open("flower.jpg")

# %%
flower_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2000x1239 at 0x5409470>

# %%
from pilkit.processors import Thumbnail

processor = Thumbnail(width=300, height=300)

# %%
thumb_image = processor.process(flower_image)

# %%
thumb_image
# Out:
# <PIL.Image.Image image mode=RGBA size=300x300 at 0x511BCB0>

# %%
thumb_image.save("thumb-300x300.png")

for quality in [100, 80, 60, 40, 20]:
    thumb_image.save("thumb-300x300-{}.jpg".format(quality), quality=quality)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\workspace\VOD-DJANGO\askenv\lib\site-packages\PIL\JpegImagePlugin.py in _save(im, fp, filename)
#     604     try:
# --> 605         rawmode = RAWMODE[im.mode]
#     606     except KeyError:
#
# KeyError: 'RGBA'
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-19-b9be6681c7fa> in <module>()
#       2
#       3 for quality in [100, 80, 60, 40, 20]:
# ----> 4     thumb_image.save("thumb-300x300-{}.jpg".format(quality), quality=quality)
#
# ~\workspace\VOD-DJANGO\askenv\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    1926
#    1927         try:
# -> 1928             save_handler(self, fp, filename)
#    1929         finally:
#    1930             # do what we can to clean up
#
# ~\workspace\VOD-DJANGO\askenv\lib\site-packages\PIL\JpegImagePlugin.py in _save(im, fp, filename)
#     605         rawmode = RAWMODE[im.mode]
#     606     except KeyError:
# --> 607         raise IOError("cannot write mode %s as JPEG" % im.mode)
#     608
#     609     info = im.encoderinfo
#
# OSError: cannot write mode RGBA as JPEG
